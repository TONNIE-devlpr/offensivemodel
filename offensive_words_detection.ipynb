# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
from better_profanity import profanity
import sklearn

# %%
df=pd.read_csv('/home/antony/Videos/study/PYTHON/AI/eGA/dataset/train.csv')

# %%
with open ("insult.txt", "r", encoding="utf-8") as file:
    words=[]
    for line in file:
        words.append(line.strip().lower())
print(words)
# Out:
# ['2 girls 1 cup', '2g1c', '4r5e', '5h1t', '5hit', 'a55', 'a_s_s', 'acrotomophilia', 'alabama hot pocket', 'alaskan pipeline', 'anal', 'anilingus', 'anus', 'apeshit', 'ar5e', 'arrse', 'arse', 'arsehole', 'ass', 'ass-fucker', 'ass-hat', 'ass-pirate', 'assbag', 'assbandit', 'assbanger', 'assbite', 'assclown', 'asscock', 'asscracker', 'asses', 'assface', 'assfucker', 'assfukka', 'assgoblin', 'asshat', 'asshead', 'asshole', 'assholes', 'asshopper', 'assjacker', 'asslick', 'asslicker', 'assmonkey', 'assmunch', 'assmuncher', 'asspirate', 'assshole', 'asssucker', 'asswad', 'asswhole', 'asswipe', 'auto erotic', 'autoerotic', 'b!tch', 'b00bs', 'b17ch', 'b1tch', 'babeland', 'baby batter', 'baby juice', 'ball gag', 'ball gravy', 'ball kicking', 'ball licking', 'ball sack', 'ball sucking', 'ballbag', 'balls', 'ballsack', 'bampot', 'bangbros', 'bareback', 'barely legal', 'barenaked', 'bastard', 'bastardo', 'bastinado', 'bbw', 'bdsm', 'beaner', 'beaners', 'beastial', 'beastiality', 'beastility', 'b
# ...

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
sia=SentimentIntensityAnalyzer()

# %%
text1=df['tweet'][2]
text1
# Out:
# '!!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby4life: You ever fuck a bitch and she start to cry? You be confused as shit'

# %%
sia.polarity_scores(text1)
# Out:
# {'neg': 0.538, 'neu': 0.462, 'pos': 0.0, 'compound': -0.955}

# %%
profanity.load_censor_words(words)
print(profanity.contains_profanity(text1))
print(profanity.censor(text1))
# Out:
# True
# !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby4life: You ever **** **** and she start to cry? You be confused as ****

# %%
text2=df['tweet'][5]
text2
# Out:
# '!!!!!!!!!!!!!!!!!!"@T_Madison_x: The shit just blows me..claim you so faithful and down for somebody but still fucking with hoes! &#128514;&#128514;&#128514;"'

# %%
sia.polarity_scores(text2)
# Out:
# {'neg': 0.101, 'neu': 0.744, 'pos': 0.155, 'compound': 0.3046}

# %%
profanity.load_censor_words(words)
print(profanity.contains_profanity(text2))
# Out:
# True

# %%
print(profanity.censor(text2))
# Out:
# !!!!!!!!!!!!!!!!!!"@T_Madison_x: The **** just blows me..claim you so faithful and down for somebody but still **** with hoes! &#128514;&#128514;&#128514;"

# %%
profanity.load_censor_words(words)
print(profanity.contains_profanity('you are shit'))
# Out:
# True

# %%
print(profanity.censor('you are shit'))
# Out:
# you are ****

# %%
sia.polarity_scores('you are shit')
# Out:
# {'neg': 0.643, 'neu': 0.357, 'pos': 0.0, 'compound': -0.5574}
